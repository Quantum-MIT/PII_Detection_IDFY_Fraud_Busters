# %% [markdown]
# ### GENERATING SOME SYNTHETIC PII DATA

# %%
# !pip install faker
# Out:
# ...
#      ---------------------------------------- 1.8/1.8 MB 4.7 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import random
import faker
import pandas as pd

# %%
# Initialize Faker library to generate fake data
fake = faker.Faker()

def generate_pii_data(num_records=1000):
    pii_data = []
    
    for _ in range(num_records):
        record = {
            'Name': fake.name(),
            'Email': fake.email(),
            'Phone Number': fake.phone_number(),
            'SSN': fake.ssn(),
            'Credit Card Number': fake.credit_card_number(),
            'IP Address': fake.ipv4(),
            'Address': fake.address().replace("\n", " "),
            'Date of Birth': fake.date_of_birth().strftime('%Y-%m-%d')
        }
        pii_data.append(record)
    
    return pd.DataFrame(pii_data)

# Generate a dataset with 1,000 records
pii_dataset = generate_pii_data(1000)

# %%
pii_dataset
# Out:
#                  Name                           Email           Phone Number  \
# 0      Kimberly Stout             kelly00@example.com     695.593.0676x70050
# 1      Jeanette Scott       barajasdennis@example.com    (758)555-1670x46243
# 2         David Brown            steven90@example.com       001-708-641-8838
# 3        Daniel Velez               ann17@example.com    (563)404-9358x22390
# 4     Angela Williams           chadbrown@example.org    (520)242-4090x64452
# ..                ...                             ...                    ...
# 995     Robert Barton           oguerrero@example.org          (537)417-1878
# 996          Amy Hunt              qbrown@example.org     996.291.3690x65088
# 997         Lisa Ward  elizabethwilkerson@example.org           256.353.2976
# 998  Sabrina Espinoza        bethanyjones@example.net  +1-945-422-7719x34073
# 999     Jennifer Cain         adamkennedy@example.com     887.598.5615x18510
#
# ...

# %%
# Save as CSV file for ingestion
pii_dataset.to_csv('pii_data.csv', index=False)
